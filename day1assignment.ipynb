# %%
lst=[1,56,98,78.5,"am",['a','b'],['c','d'],"of","python"]

# %%
lst
# Out:
# [1, 56, 98, 78.5, 'am', ['a', 'b'], ['c', 'd'], 'of', 'python']

# %%
lst[2]
# Out:
# 98

# %%
lst.append(7)

# %%
lst
# Out:
# [1,
#  56,
#  98,
#  78.5,
#  'am',
#  ['a', 'b'],
#  ['c', 'd'],
#  'of',
#  'python',
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7]

# %%
lst1=lst.copy()

# %%
lst1
# Out:
# [1,
#  56,
#  98,
#  78.5,
#  'am',
#  ['a', 'b'],
#  ['c', 'd'],
#  'of',
#  'python',
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7]

# %%
lst.clear()

# %%
lst
# Out:
# []

# %%
lst1
# Out:
# [1,
#  56,
#  98,
#  78.5,
#  'am',
#  ['a', 'b'],
#  ['c', 'd'],
#  'of',
#  'python',
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7]

# %%
lst1.count(56)
# Out:
# 1

# %%
lst1.count('a')
# Out:
# 0

# %%
lst1.insert(3,999)

# %%
lst1
# Out:
# [1,
#  56,
#  98,
#  999,
#  78.5,
#  'am',
#  ['a', 'b'],
#  ['c', 'd'],
#  'of',
#  'python',
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7]

# %%
dict={"clothes":"jeans","brand":"dressberry"}

# %%
dict
# Out:
# {'brand': 'dressberry', 'clothes': 'jeans'}

# %%
dict.get("brand")
# Out:
# 'dressberry'

# %%
dict.keys()
# Out:
# dict_keys(['clothes', 'brand'])

# %%
key1=dict.copy()

# %%
key1
# Out:
# {'brand': 'dressberry', 'clothes': 'jeans'}

# %%
dict.popitem()
# Out:
# ('brand', 'dressberry')

# %%
dict1={"brand":"necklace"}
dict.update(dict1)

# %%
dict
# Out:
# {'brand': 'necklace', 'clothes': 'jeans'}
